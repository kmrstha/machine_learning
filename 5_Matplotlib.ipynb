# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
#don't need to use plt.show()

# %%
import numpy as np

# %%
x = np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
# Plotting using matplotlib
# plt scatter

plt.scatter(x,y,c='g')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
# plt.savefig('Test.png') => To save the diagrm
# Out:
# Text(0.5, 1.0, 'Graph in 2D')

# %%
y = x*x

# %%
# plt plot

plt.plot(x,y,'r')

# %%
plt.plot(x,y,'r--')

# %%
plt.plot(x,y,'r*',linestyle='dashed', linewidth =2, markersize=12)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
# Out:
# Text(0.5, 1.0, 'Graph in 2D')

# %%
# Creating subplots

plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')
plt.subplot(2,2,4)
plt.plot(x,y,'c')

# %%
x = np.arange(1,11)
y = 3*x+5
plt.title("Matplotlib demo")
plt.xlabel("X axis caption")
plt.ylabel("Y axis caption")
plt.plot(x,y)

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# Compute the x and y coordinates for points on a sine curve

x = np.arange(0,4*np.pi, 0.1)
y = np.sin(x)
plt.title("sine wave form")

# plot the points using matplotlib
plt.plot(x,y)

# %%
# Subplot()
# compute the x and y coordinates for points on sine and cosine curves

x = np.arange(0,5*np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Set up a subplot grid that has height 2 and width 1
# and set the first such subplot as active
plt.subplot(2,1,1)

# Make the first plot
plt.plot(x,y_sin,'r--')
plt.title('Sine')

# set the second subplot as active and make the second plot
plt.subplot(2,1,2)
plt.plot(x,y_cos,'g--')
plt.title('Cosine')
# Out:
# Text(0.5, 1.0, 'Cosine')

# %%
# Bar plot

x=[2,8,10]
y=[11,16,9]

x2=[3,9,11]
y2=[6,15,7]

plt.bar(x,y,align='center')
plt.bar(x2,y2,color='g')
plt.title('Bar graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')
# Out:
# Text(0.5, 0, 'X axis')

# %% [markdown]
# ## Histograms

# %%
# Helps you to find the density on y-axis

a= np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a)
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %% [markdown]
# ## Box Plot using Matplotlib

# %%
data = [np.random.normal(0, std, 100) for std in range(1,4)]

        # rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);
# If vert=False it will be horizontally rotated
# If patch_artist=False the color will be gone

# %%
data
# Out:
# [array([-0.49890837,  1.46917735, -1.10787207,  1.16889774, -0.35655821,
#          0.26295059, -0.18102573,  0.86959879,  0.02295798,  2.00706665,
#          0.02981787,  0.32336535, -0.25156486,  0.03669138, -0.66373298,
#         -0.19761186, -0.45976864, -1.1419154 ,  1.2363317 ,  0.13530109,
#         -1.27634986,  0.36286299, -0.06296364,  1.51477527,  1.74493662,
#          0.41624237, -1.21736412, -0.36734543,  0.79284623,  1.25564169,
#          1.79542984, -0.90968444,  1.07109825, -1.17493703, -0.90711083,
#         -0.63665811,  0.21617868, -0.59537409, -1.25652854,  0.55302938,
#         -1.02872999, -0.93485712, -2.0709862 ,  0.48297871,  1.13401835,
#          0.89734403, -0.17426058, -0.24249128, -0.8849324 ,  1.25994163,
#          0.50279072,  1.25934949,  0.53160775,  0.95216563, -0.04674653,
#         -0.79942032,  0.02172709, -1.06357579,  0.42013274,  0.08062728,
#          1.0336797 , -1.53227446, -0.51796537, -1.17324853,  1.22365106,
#         -0.21590813, -2.50432762,  0.82337865,  1.62348519,  0.60706515,
#          2.00767704, -0.37633881,  0.69880684,  0.93900545, -0.46279925,
#         -1.78160203, -0.72683039,  0.45393256, -0.28226254,  0.02846751,
#         -0.58937661,  0.50374929, -2.93956165,  0.53078178,  1.84196443,
#          0.82695948, -0.38552044, -0.87229288,  1.31420989,  0.6038577 ,
#         -0.86468084,  0.14128605,  0.03737453, -0.89107468,  1.52867015,
